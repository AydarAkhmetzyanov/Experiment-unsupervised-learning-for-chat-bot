# %%
import pandas as pd
import numpy as np
df = pd.read_csv('vk.csv')
df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0   кредитная карта моментум. ею можно расплачива...
# 1           1  на дебетную карту пришло сообщение о "неразреш...
# 2           2  вопрос. почему не приходят смс о пополнении ка...
# 3           3   есть зарплатная карта сб, пользуюсь сбол. кро...
# 4           4  здраствуйте.мне пришло смс ,что одобрен предво...
#
#                                               answer
# 0    вы можете, использовать кредитую карту visa/...
# 1    по данному вопросу вы можете обратиться в сл...
# 2    по данному вопросу вы можете обратиться в сл...
# 3    по данному вопросу вы можете обратиться в сл...
# 4    потребительский кредит может быть выдан при ...

# %%
import logging
import os
import tempfile
TEMP_FOLDER = tempfile.gettempdir()
from gensim import corpora

# %%
documents = df['question'].tolist()

# %%
import re
documents = [str(x)
             .replace("тк","")
             .replace("сбербанк","банк")
             .replace("сбер","банк")
             .replace("сбербанка","банк")
             .replace("банка","банк")
             for x in documents]
documents = [re.sub(r'[^а-яА-Я ]+', '',str(x))
             for x in documents]
print(documents[1])
# Out:
# на дебетную карту пришло сообщение о неразрешенной задолженности никакой задолженности быть не может тк карта дебетная на сколько я понял это банковский косяк и с меня банк захочет взять процент как мне вернуть свои деньги

# %%
import nltk
from nltk.corpus import brown
stop_words= nltk.corpus.stopwords.words('russian')
stop_word="пожалуйста здоавствуйте"
for i in stop_words:
        stop_word=  stop_word+" "+i
stoplist = stop_word

texts = [[word for word in str(document).lower().split() if word not in stoplist] for document in documents]

# %%
# remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# %%
texts = [[token for token in text if frequency[token] > 2] for text in texts]

# %%
#lemmatize
import time
start = time.time()
import pymystem3
mystem = pymystem3.Mystem()
texts_lemmatized = [[mystem.lemmatize(token)[0] for token in text] for text in texts]
stop = time.time()

# %%
print("Время, затраченное lemmatize на обработку слов "+str((stop - start)))
# Out:
# Время, затраченное lemmatize на обработку слов 59.45220589637756

# %%
texts = texts_lemmatized
print(texts[0:3])
# Out:
# [['кредитный', 'карта', 'моментум', 'она', 'расплачиваться', 'зарубежный', 'интернет', 'магазин'], ['дебетный', 'карта', 'приходить', 'сообщение', 'задолженность', 'никакой', 'задолженность', 'тк', 'карта', 'дебетный', 'сколько', 'понимать', 'банковский', 'косяк', 'банк', 'захотеть', 'взять', 'процент', 'вернуть', 'свой', 'деньги'], ['вопрос', 'почему', 'приходить', 'смс', 'пополнение', 'карта', 'ради', 'подключный', 'мобильный', 'банк']]

# %%
dictionary = corpora.Dictionary(texts)
dictionary.save('deerwester.dict')  # store the dictionary, for future reference
print(dictionary)
# Out:
# Dictionary(6800 unique tokens: ['кредитный', 'карта', 'моментум', 'она', 'расплачиваться']...)

# %%
new_doc = "чат бот"
new_vec = dictionary.doc2bow(new_doc.lower().split())
new_vec
# Out:
# [(4628, 1)]

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize(os.path.join(TEMP_FOLDER, 'deerwester.mm'), corpus)

# %%
from gensim import corpora, models, similarities
if os.path.isfile(os.path.join(TEMP_FOLDER, 'deerwester.dict')):
    dictionary = corpora.Dictionary.load(os.path.join(TEMP_FOLDER, 'deerwester.dict'))
    corpus = corpora.MmCorpus(os.path.join(TEMP_FOLDER, 'deerwester.mm'))
else:
    print("generate data")

# %%
print(dictionary[0])
print(dictionary[1])
print(dictionary[2])
# Out:
# кредитный
# карта
# моментум

# %%
lda = models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=200, update_every=1, chunksize=10000, passes=5)

# %%
lda.print_topics(num_topics=250, num_words=10)
# Out:
# [(0,
#   '0.187*"сам" + 0.076*"секунда" + 0.069*"брат" + 0.062*"ложный" + 0.061*"банкмочь" + 0.061*"запрашиваться" + 0.061*"изменна" + 0.043*"изменение" + 0.031*"представитель" + 0.028*"услуга"'),
#  (1,
#   '0.116*"жить" + 0.081*"менеджер" + 0.080*"прописка" + 0.070*"прописывать" + 0.054*"постоянно" + 0.053*"ипотечный" + 0.050*"город" + 0.049*"рассказывать" + 0.041*"кредитование" + 0.037*"подача"'),
#  (2,
#   '0.243*"сб" + 0.119*"похоже" + 0.091*"золотой" + 0.047*"благодарный" + 0.024*"учиться" + 0.022*"партнер" + 0.022*"практика" + 0.021*"получать" + 0.020*"ктонибудь" + 0.020*"казань"'),
#  (3,
#   '0.198*"платить" + 0.197*"заплатить" + 0.112*"действующий" + 0.064*"нужно" + 0.050*"осуществление" + 0.050*"денис" + 0.047*"автоматически" + 0.038*"случай" + 0.037*"стоимость" + 0.031*"приобретать"'),
#  (4,
#   '0.287*"сообщение" + 0.150*"приходить" + 0.081*"банк" + 0.062*"пополнять" + 0.062*"действительно" + 0.039*"мочь" + 0.028*"граница" + 0.025*"мтс" + 0.023*"делать" + 0.017*"билайн"'),
#  (5,
#   '0.101*"неделя" + 0.098*"готовый" + 0.096*"забирать" + 0.095*"карта" + 0.036*"общий" + 0.035*"сказать" + 0.033*"два" + 0.030*"понятно" + 0.028*"рождение" + 0.028*"узнавать"'),
#  (6,
#   '0.347*"мой" + 0.070*"сказать" + 0.068*"план" + 0.062*"оставаться" + 0.055*"штука" + 0.053*"обезопасить" + 0.050*"тарифный" + 0.049*"делать" + 0.046*"вместо" + 0.029*"карта"'),
#  (7,
#   '0.364*"ваш" + 0.062*"видеть" + 0.052*"который" + 0.038*"сотрудник" + 0.034*"сайт" + 0.029*"такой" + 0.027*"уважение" + 0.027*"почему" + 0.024*"очень" + 0.024*"никуда"'),
#  (8,
#   '0.114*"паспорт" + 0.086*"россия" + 0.077*"необходимо" + 0.063*"гражданин" + 0.062*"банк" + 0.047*"украина" + 0.046*"спасибо" + 0.042*"рф" + 0.041*"какой" + 0.035*"документ"'),
#  (9,
#   '0.204*"звонить" + 0.090*"оператор" + 0.081*"банк" + 0.076*"номер" + 0.059*"перезванивать" + 0.056*"пао" + 0.051*"ваш" + 0.042*"связываться" + 0.032*"продукт" + 0.030*"вы"'),
#  (10,
#   '0.184*"отделение" + 0.098*"город" + 0.084*"банк" + 0.080*"друг" + 0.078*"карта" + 0.047*"мочь" + 0.042*"получать" + 0.031*"регион" + 0.025*"место" + 0.024*"обращаться"'),
#  (11,
#   '0.270*"мобильный" + 0.217*"банк" + 0.129*"подключать" + 0.085*"олючать" + 0.053*"карта" + 0.033*"онлайн" + 0.033*"услуга" + 0.025*"далее" + 0.023*"пакет" + 0.014*"полный"'),
#  (12,
#   '0.375*"один" + 0.156*"другой" + 0.131*"разный" + 0.061*"оба" + 0.045*"сумма" + 0.035*"подругой" + 0.034*"два" + 0.025*"пробовать" + 0.018*"карта" + 0.012*"правильный"'),
#  (13,
#   '0.143*"доступ" + 0.132*"доставка" + 0.129*"далеко" + 0.074*"поэтому" + 0.040*"техподдержка" + 0.037*"оповещение" + 0.026*"придт" + 0.023*"неудобно" + 0.020*"онлайн" + 0.020*"мошеннический"'),
#  (14,
#   '0.420*"номер" + 0.132*"телефон" + 0.117*"карта" + 0.075*"банк" + 0.063*"привязывать" + 0.028*"который" + 0.021*"мочь" + 0.021*"онлайн" + 0.013*"узнавать" + 0.011*"подсказывать"'),
#  (15,
#   '0.350*"кредит" + 0.106*"оформлять" + 0.072*"банк" + 0.055*"потребительский" + 0.041*"сумма" + 0.040*"погасить" + 0.040*"взять" + 0.025*"досрочно" + 0.024*"страховка" + 0.023*"привет"'),
#  (16,
#   '0.073*"сервис" + 0.070*"банкми" + 0.065*"банк" + 0.063*"требоваться" + 0.051*"отдел" + 0.049*"инн" + 0.043*"обратный" + 0.036*"связь" + 0.030*"высылать" + 0.027*"бик"'),
#  (17,
#   '0.187*"банкегательный" + 0.128*"книжка" + 0.098*"настройка" + 0.081*"банконлайн" + 0.072*"оуд" + 0.063*"вкладка" + 0.057*"недавно" + 0.056*"осторожно" + 0.050*"поход" + 0.037*"подключать"'),
#  (18,
#   '0.144*"пароль" + 0.091*"подтверждение" + 0.058*"онлайн" + 0.051*"контактный" + 0.047*"банк" + 0.045*"логин" + 0.041*"приходить" + 0.038*"пытаться" + 0.032*"вводить" + 0.031*"вход"'),
#  (19,
#   '0.180*"весь" + 0.106*"центр" + 0.088*"висеть" + 0.069*"задержка" + 0.038*"дважды" + 0.024*"приглашать" + 0.023*"проконсультировать" + 0.022*"снова" + 0.022*"вебмани" + 0.019*"колл"'),
#  (20,
#   '0.142*"монета" + 0.098*"цена" + 0.090*"банк" + 0.078*"переставать" + 0.073*"нигде" + 0.070*"блокировка" + 0.048*"находить" + 0.046*"хранить" + 0.034*"какой" + 0.033*"подсказывать"'),
#  (21,
#   '0.182*"баланс" + 0.099*"нормально" + 0.092*"карта" + 0.069*"банк" + 0.055*"такой" + 0.054*"мочь" + 0.051*"оформлять" + 0.050*"вопрос" + 0.044*"апсс" + 0.044*"удэ"'),
#  (22,
#   '0.110*"звонок" + 0.089*"сообщать" + 0.056*"относиться" + 0.050*"банк" + 0.048*"просьба" + 0.039*"обращаться" + 0.038*"попросить" + 0.032*"данный" + 0.023*"мой" + 0.019*"никакой"'),
#  (23,
#   '0.161*"карта" + 0.111*"социальный" + 0.109*"бесплатный" + 0.085*"моментум" + 0.077*"банка" + 0.052*"наличие" + 0.052*"изучать" + 0.033*"банк" + 0.032*"вирус" + 0.031*"маэстро"'),
#  (24,
#   '0.298*"ребенок" + 0.078*"требовать" + 0.037*"иметь" + 0.035*"подписывать" + 0.034*"неужели" + 0.027*"кстати" + 0.023*"сила" + 0.023*"действительный" + 0.019*"он" + 0.018*"плохо"'),
#  (25,
#   '0.153*"решать" + 0.119*"изза" + 0.060*"проблема" + 0.044*"отношение" + 0.042*"видимо" + 0.038*"надеяться" + 0.038*"банк" + 0.028*"куча" + 0.021*"тк" + 0.020*"прокуратура"'),
#  (26,
#   '0.178*"минута" + 0.140*"очередь" + 0.077*"приход" + 0.068*"живой" + 0.067*"время" + 0.026*"сохранять" + 0.025*"естественно" + 0.025*"банк" + 0.023*"складываться" + 0.022*"приходить"'),
#  (27,
#   '0.098*"знать" + 0.066*"карта" + 0.066*"оазаться" + 0.059*"тип" + 0.059*"пинкод" + 0.035*"мама" + 0.034*"также" + 0.032*"такой" + 0.031*"допускать" + 0.031*"составление"'),
#  (28,
#   '0.318*"личный" + 0.256*"кабинет" + 0.122*"раздел" + 0.063*"банк" + 0.038*"операция" + 0.023*"почему" + 0.016*"мочь" + 0.015*"онлайн" + 0.015*"узнавать" + 0.015*"карта"'),
#  (29,
#   '0.245*"хотя" + 0.096*"интересно" + 0.076*"все" + 0.073*"зависать" + 0.062*"показывать" + 0.059*"давно" + 0.058*"тыср" + 0.043*"новый" + 0.029*"такой" + 0.024*"сразу"'),
#  (30,
#   '0.153*"выписка" + 0.067*"ожидать" + 0.059*"считаться" + 0.051*"полный" + 0.048*"рекомендовать" + 0.048*"заключаться" + 0.042*"май" + 0.034*"июнь" + 0.029*"день" + 0.029*"понедельник"'),
#  (31,
#   '0.206*"комиссия" + 0.117*"любой" + 0.110*"карта" + 0.084*"средство" + 0.078*"универсальный" + 0.061*"взиматься" + 0.050*"ограничение" + 0.050*"свой" + 0.045*"счет" + 0.014*"банк"'),
#  (32,
#   '0.279*"вклад" + 0.086*"процент" + 0.073*"счет" + 0.060*"орыть" + 0.046*"сумма" + 0.045*"орытие" + 0.043*"вопрос" + 0.042*"орыто" + 0.039*"деньги" + 0.026*"пример"'),
#  (33,
#   '0.111*"стажировка" + 0.102*"филиал" + 0.076*"иметься" + 0.070*"акция" + 0.068*"банк" + 0.067*"вопрос" + 0.062*"договор" + 0.058*"задавать" + 0.040*"специалист" + 0.034*"подсказывать"'),
#  (34,
#   '0.112*"этот" + 0.109*"код" + 0.093*"страница" + 0.075*"вводить" + 0.061*"создавать" + 0.050*"карта" + 0.038*"забывать" + 0.036*"канал" + 0.033*"пин" + 0.033*"вспомнить"'),
#  (35,
#   '0.150*"операция" + 0.073*"списание" + 0.071*"зачисление" + 0.060*"списывать" + 0.058*"никакой" + 0.054*"карта" + 0.041*"выполнять" + 0.038*"пропадать" + 0.036*"сумма" + 0.035*"онлайн"'),
#  (36,
#   '0.320*"какой" + 0.144*"образ" + 0.084*"подсказывать" + 0.069*"номер" + 0.058*"пенза" + 0.017*"активация" + 0.017*"свидетельство" + 0.016*"абсолютно" + 0.015*"какимто" + 0.014*"предусматривать"'),
#  (37,
#   '0.336*"снимать" + 0.160*"деньги" + 0.118*"карта" + 0.069*"банк" + 0.044*"мочь" + 0.027*"крым" + 0.021*"накладывать" + 0.021*"светиться" + 0.018*"сказать" + 0.013*"понимать"'),
#  (38,
#   '0.158*"процент" + 0.137*"момент" + 0.089*"месяц" + 0.064*"данный" + 0.062*"истечение" + 0.039*"делаться" + 0.036*"подсказывать" + 0.035*"пенсионер" + 0.029*"сказать" + 0.029*"заранее"'),
#  (39,
#   '0.143*"банккнижка" + 0.081*"использовать" + 0.081*"область" + 0.073*"банк" + 0.066*"деньги" + 0.065*"карта" + 0.053*"переводить" + 0.053*"здраствовать" + 0.053*"фото" + 0.051*"онлайн"'),
#  (40,
#   '0.105*"пенсия" + 0.098*"вчера" + 0.071*"вариант" + 0.061*"банк" + 0.056*"лично" + 0.052*"информация" + 0.050*"направлять" + 0.047*"потратить" + 0.043*"мочь" + 0.042*"время"'),
#  (41,
#   '0.091*"почему" + 0.090*"банк" + 0.087*"онлайн" + 0.075*"недоступный" + 0.072*"мир" + 0.065*"заходить" + 0.056*"поздно" + 0.045*"вопрос" + 0.037*"форма" + 0.035*"временно"'),
#  (42,
#   '0.210*"пополнение" + 0.150*"также" + 0.094*"пополнять" + 0.082*"авторизация" + 0.065*"сторона" + 0.065*"перекредитование" + 0.029*"убирать" + 0.026*"возможность" + 0.025*"банк" + 0.019*"бумажка"'),
#  (43,
#   '0.134*"ипотека" + 0.064*"сотрудничать" + 0.061*"квартира" + 0.047*"предоставлять" + 0.039*"какой" + 0.038*"хотеть" + 0.035*"жена" + 0.031*"банкх" + 0.031*"мочь" + 0.030*"получать"'),
#  (44,
#   '0.202*"погашение" + 0.155*"большой" + 0.068*"кровный" + 0.056*"консультант" + 0.055*"сумма" + 0.048*"досрочный" + 0.038*"спасибо" + 0.031*"такой" + 0.022*"неправильно" + 0.019*"нужно"'),
#  (45,
#   '0.139*"заранее" + 0.110*"спасибо" + 0.109*"повод" + 0.105*"банк" + 0.086*"продавать" + 0.065*"талант" + 0.046*"ваш" + 0.045*"подарок" + 0.041*"обращаться" + 0.036*"стоять"'),
#  (46,
#   '0.135*"безопасность" + 0.108*"интернет" + 0.097*"служба" + 0.078*"карта" + 0.064*"заказ" + 0.063*"както" + 0.050*"поддержка" + 0.040*"средство" + 0.028*"главное" + 0.027*"совершать"'),
#  (47,
#   '0.180*"офис" + 0.104*"банк" + 0.095*"руководитель" + 0.079*"получать" + 0.067*"приходиться" + 0.067*"собираться" + 0.056*"прошлый" + 0.047*"выполнять" + 0.036*"таки" + 0.027*"промой"'),
#  (48,
#   '0.212*"нужный" + 0.200*"регистрация" + 0.182*"банк" + 0.088*"онлайн" + 0.050*"подсказывать" + 0.029*"мастер" + 0.021*"она" + 0.019*"суббота" + 0.019*"карда" + 0.018*"кнопка"'),
#  (49,
#   '0.559*"мошенник" + 0.108*"выдача" + 0.061*"перевыпущенный" + 0.042*"карта" + 0.022*"кредиу" + 0.018*"подлежать" + 0.017*"мгновенный" + 0.012*"ложить" + 0.011*"написать" + 0.010*"получать"'),
#  (50,
#   '0.493*"хотеть" + 0.066*"размер" + 0.064*"банк" + 0.063*"покупать" + 0.049*"узнавать" + 0.047*"оформлять" + 0.042*"считать" + 0.040*"начисляться" + 0.028*"карта" + 0.016*"прочитывать"'),
#  (51,
#   '0.454*"год" + 0.071*"январь" + 0.058*"ипотека" + 0.057*"первый" + 0.048*"уменьшать" + 0.031*"назад" + 0.024*"месяц" + 0.022*"выплата" + 0.017*"взнос" + 0.011*"работа"'),
#  (52,
#   '0.100*"расход" + 0.088*"внесение" + 0.084*"опция" + 0.078*"одновременно" + 0.053*"банк" + 0.052*"подсказывать" + 0.043*"режим" + 0.038*"выходной" + 0.036*"заниматься" + 0.035*"некоторые"'),
#  (53,
#   '0.190*"банковский" + 0.123*"два" + 0.119*"запрос" + 0.068*"место" + 0.054*"регион" + 0.049*"карта" + 0.048*"должный" + 0.045*"который" + 0.044*"счет" + 0.044*"перевод"'),
#  (54,
#   '0.270*"узнавать" + 0.202*"очень" + 0.141*"хотеться" + 0.106*"банк" + 0.077*"карта" + 0.051*"ваш" + 0.012*"знать" + 0.011*"бред" + 0.008*"девочка" + 0.007*"честно"'),
#  (55,
#   '0.158*"адрес" + 0.074*"электронный" + 0.072*"автомат" + 0.063*"присылать" + 0.060*"письмо" + 0.044*"почитать" + 0.043*"почта" + 0.038*"банк" + 0.032*"налог" + 0.030*"бесплатно"'),
#  (56,
#   '0.357*"дебетовый" + 0.263*"карта" + 0.060*"получать" + 0.054*"классический" + 0.052*"действовать" + 0.019*"наличка" + 0.018*"банк" + 0.017*"подсказывать" + 0.016*"онлайн" + 0.014*"сделать"'),
#  (57,
#   '0.452*"рубль" + 0.080*"скидывать" + 0.043*"русский" + 0.042*"исполняться" + 0.040*"граф" + 0.040*"сумма" + 0.037*"примерно" + 0.029*"сколько" + 0.026*"промокод" + 0.021*"мало"'),
#  (58,
#   '0.284*"карта" + 0.182*"обслуживание" + 0.089*"пользоваться" + 0.079*"конверт" + 0.064*"годовой" + 0.048*"сказать" + 0.029*"утерять" + 0.020*"оформлять" + 0.014*"который" + 0.014*"получать"'),
#  (59,
#   '0.310*"банкомат" + 0.090*"карта" + 0.085*"снятие" + 0.066*"банк" + 0.062*"наличные" + 0.053*"деньги" + 0.028*"наличный" + 0.028*"комиссия" + 0.024*"вносить" + 0.024*"дедушка"'),
#  (60,
#   '0.171*"принимать" + 0.131*"стоять" + 0.091*"сколько" + 0.090*"предлагать" + 0.078*"мера" + 0.067*"почему" + 0.053*"поле" + 0.053*"хороший" + 0.044*"написать" + 0.037*"сайт"'),
#  (61,
#   '0.115*"ситуация" + 0.082*"происходить" + 0.065*"такой" + 0.058*"факт" + 0.044*"сталкиваться" + 0.034*"предупреждать" + 0.032*"выяснять" + 0.030*"потратить" + 0.028*"сюда" + 0.027*"число"'),
#  (62,
#   '0.234*"заводить" + 0.115*"банкчерез" + 0.111*"нету" + 0.111*"оценочный" + 0.077*"посоветовать" + 0.043*"карта" + 0.042*"мочь" + 0.023*"банк" + 0.016*"аккредитовать" + 0.014*"обязанность"'),
#  (63,
#   '0.081*"доллар" + 0.070*"карта" + 0.068*"валюта" + 0.061*"расплачиваться" + 0.061*"банк" + 0.048*"рублевый" + 0.043*"мастеркард" + 0.035*"мочь" + 0.028*"неверный" + 0.027*"иностранный"'),
#  (64,
#   '0.123*"прийти" + 0.105*"потерять" + 0.084*"продлять" + 0.072*"добавлять" + 0.050*"скоро" + 0.045*"апрель" + 0.040*"делать" + 0.036*"мочь" + 0.032*"приезжать" + 0.025*"карта"'),
#  (65,
#   '0.373*"кредитный" + 0.232*"карта" + 0.043*"зарплатной" + 0.031*"период" + 0.028*"держатель" + 0.025*"банк" + 0.022*"задолженность" + 0.021*"мочь" + 0.018*"вопрос" + 0.016*"льготный"'),
#  (66,
#   '0.214*"оплачивать" + 0.151*"оплата" + 0.106*"покупка" + 0.057*"магазин" + 0.045*"чек" + 0.040*"сумма" + 0.037*"интернет" + 0.036*"карта" + 0.026*"жкх" + 0.025*"вчера"'),
#  (67,
#   '0.106*"карта" + 0.091*"поступать" + 0.085*"пора" + 0.083*"деньги" + 0.077*"сей" + 0.062*"средство" + 0.056*"денежный" + 0.056*"банк" + 0.053*"пенсионный" + 0.037*"утро"'),
#  (68,
#   '0.234*"платеж" + 0.095*"терминал" + 0.044*"видно" + 0.041*"проводить" + 0.038*"операция" + 0.032*"система" + 0.028*"банк" + 0.022*"чек" + 0.016*"проведение" + 0.015*"проблема"'),
#  (69,
#   '0.164*"сколько" + 0.155*"карта" + 0.067*"долго" + 0.061*"банк" + 0.051*"московский" + 0.048*"перевод" + 0.044*"осуществляться" + 0.040*"регион" + 0.036*"время" + 0.033*"идти"'),
#  (70,
#   '0.437*"человек" + 0.092*"спустя" + 0.056*"сомневаться" + 0.055*"каково" + 0.036*"указанный" + 0.029*"переводиться" + 0.027*"деньги" + 0.023*"другой" + 0.023*"карта" + 0.021*"переводить"'),
#  (71,
#   '0.099*"сентябрь" + 0.096*"март" + 0.094*"уп" + 0.086*"получаться" + 0.079*"планировать" + 0.072*"цифра" + 0.050*"нужно" + 0.036*"украсть" + 0.034*"ошибаться" + 0.030*"валютный"'),
#  (72,
#   '0.128*"позвонить" + 0.121*"линия" + 0.115*"горячий" + 0.088*"думать" + 0.074*"сказать" + 0.071*"случай" + 0.062*"звонить" + 0.058*"чтото" + 0.053*"говорить" + 0.032*"ждать"'),
#  (73,
#   '0.140*"мес" + 0.128*"логина" + 0.115*"тысяча" + 0.089*"программа" + 0.088*"страхование" + 0.074*"верить" + 0.052*"жизнь" + 0.034*"обязательный" + 0.025*"увеличение" + 0.019*"сказать"'),
#  (74,
#   '0.131*"конец" + 0.109*"никак" + 0.106*"дополнительный" + 0.060*"внимание" + 0.048*"связанный" + 0.034*"восстановление" + 0.031*"какойто" + 0.030*"удобно" + 0.028*"должный" + 0.026*"полгода"'),
#  (75,
#   '0.210*"документ" + 0.076*"какой" + 0.062*"нужный" + 0.049*"необходимый" + 0.045*"наоборот" + 0.045*"подтверждать" + 0.025*"дальнейший" + 0.024*"банк" + 0.024*"родственник" + 0.021*"нужно"'),
#  (76,
#   '0.158*"кто" + 0.104*"родитель" + 0.048*"обращаться" + 0.045*"существовать" + 0.042*"копия" + 0.035*"оазывать" + 0.030*"сказать" + 0.027*"банк" + 0.026*"хватать" + 0.023*"бухгалтерия"'),
#  (77,
#   '0.076*"банк" + 0.059*"турция" + 0.057*"уничтожать" + 0.037*"ячейка" + 0.035*"инициатива" + 0.035*"сказать" + 0.029*"китайский" + 0.028*"честь" + 0.024*"тайланд" + 0.023*"хмао"'),
#  (78,
#   '0.142*"уточнять" + 0.136*"организация" + 0.090*"группа" + 0.052*"возврат" + 0.032*"затем" + 0.025*"вопрос" + 0.023*"администратор" + 0.023*"никто" + 0.019*"какой" + 0.019*"подождать"'),
#  (79,
#   '0.249*"ответ" + 0.161*"обращение" + 0.092*"крупный" + 0.048*"максимальный" + 0.047*"оно" + 0.034*"данна" + 0.027*"рассматривать" + 0.027*"вопрос" + 0.022*"получать" + 0.021*"банк"'),
#  (80,
#   '0.143*"перечислять" + 0.123*"деньги" + 0.118*"разрешать" + 0.075*"туда" + 0.069*"обычный" + 0.058*"карта" + 0.055*"банк" + 0.041*"яндекс" + 0.032*"втб" + 0.031*"переводить"'),
#  (81,
#   '0.183*"смочь" + 0.175*"карта" + 0.152*"виза" + 0.055*"стоить" + 0.055*"допускать" + 0.055*"сколько" + 0.049*"качество" + 0.049*"банк" + 0.022*"классик" + 0.021*"мочь"'),
#  (82,
#   '0.217*"перевод" + 0.165*"карта" + 0.133*"банк" + 0.073*"деньги" + 0.048*"переводить" + 0.029*"сделать" + 0.029*"суи" + 0.026*"клиент" + 0.026*"получатель" + 0.025*"другой"'),
#  (83,
#   '0.173*"предложение" + 0.139*"доля" + 0.104*"условие" + 0.102*"одобрение" + 0.083*"такой" + 0.025*"персональный" + 0.020*"сестра" + 0.019*"быть" + 0.019*"млн" + 0.018*"положенный"'),
#  (84,
#   '0.273*"москва" + 0.178*"быстро" + 0.142*"карта" + 0.113*"цель" + 0.083*"виртуальный" + 0.059*"мочь" + 0.021*"тп" + 0.008*"банк" + 0.006*"вопрос" + 0.006*"явно"'),
#  (85,
#   '0.394*"отвечать" + 0.132*"спрашивать" + 0.091*"вопрос" + 0.069*"наверное" + 0.020*"расчет" + 0.020*"столько" + 0.020*"постоянный" + 0.017*"понимать" + 0.016*"предыдущий" + 0.013*"участник"'),
#  (86,
#   '0.107*"егор" + 0.106*"вызывать" + 0.094*"городской" + 0.079*"запрашивать" + 0.071*"мошенничество" + 0.061*"овердрафт" + 0.044*"некий" + 0.026*"ведомо" + 0.026*"новосибирск" + 0.024*"мой"'),
#  (87,
#   '0.342*"лицо" + 0.066*"ипать" + 0.043*"закинуть" + 0.035*"причем" + 0.033*"возвращаться" + 0.024*"физ" + 0.024*"повышать" + 0.023*"юр" + 0.022*"банк" + 0.021*"что"'),
#  (88,
#   '0.166*"указывать" + 0.087*"смотреть" + 0.085*"арест" + 0.083*"пристав" + 0.062*"который" + 0.059*"судебный" + 0.042*"данный" + 0.038*"помимо" + 0.038*"альфабанк" + 0.035*"место"'),
#  (89,
#   '0.166*"сотрудница" + 0.104*"случайно" + 0.066*"лишний" + 0.050*"томчто" + 0.045*"доставать" + 0.035*"проводиться" + 0.033*"попадаться" + 0.024*"банк" + 0.024*"картун" + 0.023*"самообслуживание"'),
#  (90,
#   '0.116*"имя" + 0.094*"список" + 0.083*"писать" + 0.075*"мошенница" + 0.061*"быть" + 0.057*"банк" + 0.052*"такой" + 0.046*"осторожный" + 0.044*"написать" + 0.044*"заблокировать"'),
#  (91,
#   '0.196*"карточка" + 0.148*"реквизит" + 0.124*"посмотреть" + 0.065*"банк" + 0.050*"почемуто" + 0.042*"узнавать" + 0.038*"житель" + 0.035*"карта" + 0.031*"мочь" + 0.027*"мой"'),
#  (92,
#   '0.169*"онлайн" + 0.146*"банк" + 0.119*"приложение" + 0.097*"мочь" + 0.090*"зайти" + 0.065*"появляться" + 0.061*"входить" + 0.046*"отображаться" + 0.026*"писать" + 0.019*"карта"'),
#  (93,
#   '0.226*"счт" + 0.098*"закрывать" + 0.095*"лицевой" + 0.085*"нужно" + 0.081*"ссылка" + 0.047*"ехать" + 0.039*"заявление" + 0.035*"писать" + 0.028*"придумывать" + 0.028*"информирование"'),
#  (94,
#   '0.178*"деньги" + 0.168*"вернуть" + 0.055*"телефонный" + 0.053*"обратно" + 0.041*"знакомый" + 0.037*"купюра" + 0.035*"нужно" + 0.032*"ждать" + 0.029*"время" + 0.027*"банк"'),
#  (95,
#   '0.169*"руб" + 0.066*"долг" + 0.064*"брать" + 0.055*"сумма" + 0.040*"просрочка" + 0.037*"история" + 0.035*"право" + 0.029*"около" + 0.023*"задолженность" + 0.021*"банк"'),
#  (96,
#   '0.140*"получение" + 0.111*"банк" + 0.096*"постановление" + 0.067*"получать" + 0.061*"высвечиваться" + 0.060*"справка" + 0.055*"доверенность" + 0.041*"подсказывать" + 0.037*"узнавать" + 0.035*"счет"'),
#  (97,
#   '0.157*"находить" + 0.101*"компания" + 0.080*"сайт" + 0.069*"мочь" + 0.067*"банк" + 0.063*"личка" + 0.061*"написать" + 0.053*"искать" + 0.048*"лс" + 0.041*"который"'),
#  (98,
#   '0.357*"помогать" + 0.068*"карта" + 0.065*"разбираться" + 0.060*"глупость" + 0.059*"ульяновск" + 0.040*"выходить" + 0.036*"свой" + 0.024*"другой" + 0.022*"давать" + 0.020*"обманывать"'),
#  (99,
#   '0.229*"выпускать" + 0.094*"колво" + 0.093*"бан" + 0.087*"июль" + 0.077*"август" + 0.044*"свое" + 0.034*"конкретный" + 0.033*"утверждать" + 0.029*"тратить" + 0.024*"кредие"'),
#  (100,
#   '0.199*"карта" + 0.138*"заблокировать" + 0.131*"новый" + 0.111*"старый" + 0.046*"банк" + 0.037*"переставать" + 0.031*"закрытие" + 0.029*"давно" + 0.026*"вопрос" + 0.026*"заявление"'),
#  (101,
#   '0.120*"плата" + 0.102*"срочный" + 0.100*"правда" + 0.061*"именной" + 0.049*"симкарта" + 0.039*"карта" + 0.038*"они" + 0.036*"класть" + 0.034*"заработный" + 0.030*"вопрос"'),
#  (102,
#   '0.325*"списываться" + 0.139*"февраль" + 0.101*"карта" + 0.047*"небольшой" + 0.046*"район" + 0.042*"стипендия" + 0.036*"пришлый" + 0.019*"начало" + 0.013*"обстоятельство" + 0.012*"деньги"'),
#  (103,
#   '0.168*"кошелек" + 0.097*"киви" + 0.069*"банк" + 0.056*"блокировать" + 0.053*"деньги" + 0.050*"карта" + 0.049*"попадать" + 0.034*"полиция" + 0.030*"переводить" + 0.028*"отпуск"'),
#  (104,
#   '0.205*"спасибо" + 0.201*"бонус" + 0.185*"пользоваться" + 0.077*"ставка" + 0.042*"оставаться" + 0.040*"процентный" + 0.032*"тариф" + 0.019*"пользователь" + 0.017*"банк" + 0.017*"продолжать"'),
#  (105,
#   '0.166*"мы" + 0.109*"именно" + 0.060*"кроме" + 0.060*"одобрять" + 0.059*"число" + 0.056*"страховка" + 0.043*"нужно" + 0.043*"какой" + 0.037*"буквально" + 0.034*"посчитать"'),
#  (106,
#   '0.113*"дозваниваться" + 0.086*"официально" + 0.070*"работать" + 0.035*"банк" + 0.033*"мочь" + 0.029*"заканчивать" + 0.028*"малый" + 0.027*"отделение" + 0.024*"блокироваться" + 0.023*"итак"'),
#  (107,
#   '0.117*"тыс" + 0.080*"зп" + 0.064*"ежемесячный" + 0.063*"каков" + 0.060*"сумма" + 0.058*"порядок" + 0.057*"взять" + 0.048*"платеж" + 0.040*"сколько" + 0.038*"хотеть"'),
#  (108,
#   '0.147*"договор" + 0.124*"банк" + 0.100*"онлайн" + 0.083*"оплачивать" + 0.053*"пункт" + 0.053*"значит" + 0.052*"оаз" + 0.041*"жкх" + 0.040*"единый" + 0.038*"сайт"'),
#  (109,
#   '0.222*"деньги" + 0.110*"проверять" + 0.095*"доходить" + 0.084*"карта" + 0.067*"касса" + 0.046*"мой" + 0.043*"верный" + 0.035*"баланс" + 0.033*"уходить" + 0.032*"происходить"'),
#  (110,
#   '0.150*"превышать" + 0.114*"якобы" + 0.074*"достаточно" + 0.049*"переходить" + 0.042*"писать" + 0.034*"лимит" + 0.031*"немного" + 0.028*"ожидание" + 0.027*"выполнение" + 0.022*"дама"'),
#  (111,
#   '0.167*"день" + 0.056*"течение" + 0.054*"сказать" + 0.042*"банк" + 0.033*"деньги" + 0.030*"рабочий" + 0.025*"отделение" + 0.025*"зачислять" + 0.024*"ходить" + 0.023*"заявление"'),
#  (112,
#   '0.170*"ошибка" + 0.081*"попый" + 0.070*"компьютер" + 0.053*"невозможно" + 0.039*"идентификатор" + 0.036*"выдавать" + 0.036*"устанавливать" + 0.024*"смог" + 0.021*"простой" + 0.019*"бумага"'),
#  (113,
#   '0.341*"иметь" + 0.100*"разница" + 0.069*"драгоценный" + 0.035*"время" + 0.033*"деваться" + 0.032*"уезжать" + 0.025*"попытаться" + 0.022*"почему" + 0.017*"голос" + 0.016*"регулярно"'),
#  (114,
#   '0.072*"статус" + 0.056*"супер" + 0.038*"санктпетербург" + 0.036*"результат" + 0.032*"закон" + 0.032*"банк" + 0.031*"сожаление" + 0.028*"защита" + 0.022*"улица" + 0.021*"совершенно"'),
#  (115,
#   '0.235*"данные" + 0.112*"поменять" + 0.078*"слово" + 0.062*"речь" + 0.050*"банк" + 0.047*"паспортный" + 0.045*"кодовый" + 0.045*"сменить" + 0.041*"онлайн" + 0.037*"карта"'),
#  (116,
#   '0.151*"карта" + 0.125*"оставаться" + 0.067*"перевыпускать" + 0.057*"номер" + 0.040*"старый" + 0.038*"лицевой" + 0.031*"деньги" + 0.030*"работник" + 0.027*"докладывать" + 0.026*"социальный"'),
#  (117,
#   '0.169*"декабрь" + 0.151*"беларусь" + 0.151*"основной" + 0.096*"притворяться" + 0.049*"республика" + 0.034*"отрицательный" + 0.028*"согласно" + 0.021*"государство" + 0.020*"отдельный" + 0.020*"незаконный"'),
#  (118,
#   '0.237*"добрый" + 0.215*"время" + 0.073*"сутки" + 0.057*"какой" + 0.045*"день" + 0.036*"спасибо" + 0.035*"зарание" + 0.034*"течение" + 0.019*"случаться" + 0.016*"подсказывать"'),
#  (119,
#   '0.136*"аккаунт" + 0.119*"вид" + 0.094*"увидеть" + 0.090*"отпадать" + 0.076*"именно" + 0.057*"сидеть" + 0.042*"сертификат" + 0.038*"мол" + 0.034*"настоящий" + 0.029*"утеря"'),
#  (120,
#   '0.207*"начинать" + 0.089*"выходить" + 0.067*"дома" + 0.062*"неизвестный" + 0.058*"диалог" + 0.050*"остаток" + 0.047*"часть" + 0.032*"потеря" + 0.029*"маленький" + 0.024*"платежный"'),
#  (121,
#   '0.156*"дело" + 0.105*"уходить" + 0.102*"срочно" + 0.066*"минус" + 0.062*"карта" + 0.052*"сегодня" + 0.042*"направление" + 0.041*"обстоять" + 0.040*"продливать" + 0.030*"какой"'),
#  (122,
#   '0.145*"либо" + 0.078*"перечисление" + 0.052*"база" + 0.046*"какой" + 0.045*"некоторый" + 0.036*"означать" + 0.035*"разрешение" + 0.028*"возраст" + 0.027*"отличаться" + 0.025*"орган"'),
#  (123,
#   '0.222*"проверка" + 0.127*"корректный" + 0.045*"тишина" + 0.043*"целый" + 0.039*"машина" + 0.032*"странный" + 0.030*"известный" + 0.027*"впервые" + 0.024*"мом" + 0.018*"юань"'),
#  (124,
#   '0.169*"давать" + 0.102*"клиент" + 0.057*"являться" + 0.056*"объяснять" + 0.055*"фио" + 0.054*"основание" + 0.053*"какой" + 0.044*"почему" + 0.037*"прием" + 0.033*"персонал"'),
#  (125,
#   '0.219*"проблема" + 0.182*"такой" + 0.064*"должно" + 0.054*"попробовать" + 0.051*"проходить" + 0.044*"решение" + 0.043*"делать" + 0.039*"написать" + 0.038*"евгений" + 0.038*"переустановить"'),
#  (126,
#   '0.088*"курс" + 0.057*"евро" + 0.048*"банк" + 0.047*"страна" + 0.039*"сниматься" + 0.037*"какието" + 0.036*"какой" + 0.035*"российский" + 0.030*"сначала" + 0.029*"доллар"'),
#  (127,
#   '0.091*"полагать" + 0.085*"деньги" + 0.060*"час" + 0.044*"средство" + 0.042*"называться" + 0.041*"поступление" + 0.033*"однако" + 0.032*"банк" + 0.032*"возвращать" + 0.030*"технический"'),
#  (128,
#   '0.226*"карта" + 0.118*"заказывать" + 0.101*"дизайн" + 0.085*"молодежный" + 0.064*"индивидуальный" + 0.058*"заявка" + 0.050*"отменять" + 0.039*"моментальный" + 0.030*"заказ" + 0.027*"оформлять"'),
#  (129,
#   '0.214*"вообще" + 0.207*"лимит" + 0.085*"муж" + 0.080*"должный" + 0.078*"платный" + 0.066*"какой" + 0.030*"сгорать" + 0.026*"горячий" + 0.026*"увеличивать" + 0.022*"банк"'),
#  (130,
#   '0.142*"рука" + 0.095*"робот" + 0.046*"который" + 0.035*"рядом" + 0.033*"дом" + 0.033*"проект" + 0.030*"собственно" + 0.029*"какоето" + 0.028*"вставлять" + 0.026*"замораживать"'),
#  (131,
#   '0.174*"дата" + 0.132*"рано" + 0.116*"восстанавливать" + 0.054*"квитанция" + 0.052*"задолжность" + 0.047*"ввиду" + 0.045*"штраф" + 0.039*"подсказывать" + 0.027*"оплачивать" + 0.025*"выплачивать"'),
#  (132,
#   '0.206*"просить" + 0.145*"вакансия" + 0.096*"банк" + 0.059*"студент" + 0.052*"женщина" + 0.049*"вообще" + 0.039*"мой" + 0.039*"информация" + 0.026*"бизнес" + 0.022*"передавать"'),
#  (133,
#   '0.465*"счет" + 0.058*"банк" + 0.046*"расчетный" + 0.045*"официальный" + 0.030*"начисление" + 0.025*"деньги" + 0.023*"мочь" + 0.021*"свой" + 0.018*"ноябрь" + 0.014*"определенный"'),
#  (134,
#   '0.279*"работать" + 0.103*"банк" + 0.069*"отсутствовать" + 0.057*"нга" + 0.046*"подсказывать" + 0.039*"отделение" + 0.039*"обл" + 0.038*"работа" + 0.031*"завтра" + 0.027*"день"'),
#  (135,
#   '0.218*"причина" + 0.125*"копилка" + 0.070*"разблокировать" + 0.052*"наш" + 0.043*"карта" + 0.042*"заблокировать" + 0.025*"уведомлять" + 0.024*"банк" + 0.020*"установленный" + 0.020*"ничто"'),
#  (136,
#   '0.161*"заявление" + 0.065*"написать" + 0.053*"мой" + 0.046*"я" + 0.035*"карта" + 0.034*"выпуск" + 0.027*"отделение" + 0.027*"итоговый" + 0.024*"банк" + 0.023*"претензия"'),
#  (137,
#   '0.183*"заявка" + 0.084*"подавать" + 0.065*"банк" + 0.059*"оформление" + 0.046*"кредит" + 0.043*"заполнять" + 0.034*"ждать" + 0.030*"оставлять" + 0.030*"месяц" + 0.030*"смысл"'),
#  (138,
#   '0.157*"моб" + 0.125*"информация" + 0.060*"здравстовать" + 0.058*"кв" + 0.057*"дока" + 0.053*"владелец" + 0.037*"использование" + 0.033*"собственный" + 0.019*"предоставлять" + 0.016*"средство"'),
#  (139,
#   '0.213*"срок" + 0.211*"карта" + 0.127*"действие" + 0.057*"истекать" + 0.054*"новый" + 0.037*"заканчиваться" + 0.037*"получать" + 0.017*"мочь" + 0.016*"банк" + 0.016*"случай"'),
#  (140,
#   '0.311*"приходить" + 0.273*"смс" + 0.031*"сегодня" + 0.030*"отправлять" + 0.025*"такой" + 0.025*"карта" + 0.023*"вроде" + 0.022*"оповещение" + 0.017*"банк" + 0.017*"сумма"'),
#  (141,
#   '0.109*"совершать" + 0.086*"данна" + 0.083*"карта" + 0.078*"выпускаться" + 0.076*"выбирать" + 0.071*"подозрение" + 0.064*"деньгикоторой" + 0.047*"операция" + 0.039*"мочь" + 0.019*"другой"'),
#  (142,
#   '0.155*"перевыпуск" + 0.105*"фамилия" + 0.084*"идт" + 0.072*"смена" + 0.064*"карта" + 0.063*"активировать" + 0.062*"отделение" + 0.047*"менять" + 0.043*"выдавать" + 0.037*"сегодня"'),
#  (143,
#   '0.276*"второй" + 0.148*"первый" + 0.136*"работник" + 0.079*"звонок" + 0.057*"банк" + 0.053*"прощать" + 0.047*"ненужный" + 0.024*"карта" + 0.024*"сегодня" + 0.014*"положительный"'),
#  (144,
#   '0.194*"деньги" + 0.116*"переводить" + 0.082*"карта" + 0.075*"банк" + 0.063*"счта" + 0.060*"пойти" + 0.042*"сумма" + 0.041*"ждать" + 0.038*"пока" + 0.026*"сразу"'),
#  (145,
#   '0.132*"изменяться" + 0.118*"менять" + 0.108*"подсказывать" + 0.093*"раз" + 0.079*"карта" + 0.076*"подключение" + 0.058*"обменять" + 0.058*"посещение" + 0.053*"начинать" + 0.033*"копейка"'),
#  (146,
#   '0.204*"проходить" + 0.112*"жалоба" + 0.087*"день" + 0.083*"отправлять" + 0.052*"обещать" + 0.046*"суть" + 0.042*"мат" + 0.039*"поставлять" + 0.039*"улучшение" + 0.039*"квартал"'),
#  (147,
#   '0.325*"сотрудник" + 0.094*"банк" + 0.046*"представляться" + 0.040*"минимальный" + 0.035*"доступный" + 0.031*"девушка" + 0.020*"вопрос" + 0.019*"развод" + 0.019*"всякий" + 0.019*"сказать"'),
#  (148,
#   '0.213*"услуга" + 0.156*"возможность" + 0.094*"подключать" + 0.075*"автоплатеж" + 0.065*"карта" + 0.044*"спасибо" + 0.037*"сделать" + 0.033*"платж" + 0.020*"олючать" + 0.019*"помнить"'),
#  (149,
#   '0.139*"зарплатный" + 0.113*"пособие" + 0.087*"кредия" + 0.078*"детский" + 0.066*"зарплата" + 0.065*"карта" + 0.051*"мочь" + 0.047*"судя" + 0.046*"получение" + 0.032*"оформлять"')]

# %%
index = similarities.MatrixSimilarity(lda[corpus])

# %%
lda.save('model.lsi') # same for tfidf, lda, ...
lda = models.LsiModel.load('model.lsi')

import pickle
pickle.dump( index, open( "index.p", "wb" ) )

index = pickle.load( open( "index.p", "rb" ) )
# Out:
# WARNING:root:failed to load projection from model.lsi.projection: [Errno 2] No such file or directory: 'model.lsi.projection'

# %%
import nlu_core
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1cf24a3f620f> in <module>()
# ----> 1 import nlu_core
#       2
#
# ~/Documents/testchatbot/nlu_core.py in <module>()
#      17
#      18
# ---> 19 dictionary = corpora.Dictionary.load(os.path.join(TEMP_FOLDER, 'deerwester.dict'))
#      20 lda = models.LsiModel.load('model.lsi')
#      21 index = pickle.load( open( "index.p", "rb" ) )
#
# NameError: name 'TEMP_FOLDER' is not defined

# %%
#"  вы можете, использовать кредитую карту visa/mastercard cre..
print(utterance_to_result("кредитная карта моментум. ею можно расплачиваться в зарубежных интернет магазинах?"))
#test
print(utterance_to_result("можно ли расплатиться кредитной картой моментумом в заграничных интернет магазинах"))
#test
print(utterance_to_result("мне нужно оплатить покупку в интернет магазине кредитной картой моментум"))
# Out:
# [(23, 0.14190884239429621), (48, 0.11313940078482519), (63, 0.12216916355472332), (65, 0.16602142986472973), (66, 0.23638754326767031), (126, 0.11370695346708941)]
#   вы можете, использовать кредитую карту visa/mastercard credit momentum для оплаты покупок в интернете при условии, что сайт поддерживает обслуживание данного вида карт.
# [(0, 1.0), (4826, 0.75312287), (8205, 0.73117661), (34320, 0.71939576), (14892, 0.71575278)]
# [(23, 0.15993694822986129), (42, 0.12821331174188305), (63, 0.13751957406982146), (65, 0.18743923642000879), (66, 0.26605759620509051)]
#   вы можете, использовать кредитую карту visa/mastercard credit momentum для оплаты покупок в интернете при условии, что сайт поддерживает обслуживание данного вида карт.
# [(0, 0.8606196), (4826, 0.78893828), (8205, 0.76623642), (34320, 0.75371224), (19673, 0.74804169)]
# [(23, 0.13375163036419449), (65, 0.22641479735254247), (66, 0.53094468339438039)]
#  совершать оплату услуг можно в системе сбербанк онлайн. для этого рекомендуем получить идентификатор пользователя и постоянный пароль для входа. идентификатор можно получить в контактном центре банка по телефону 8-800-555-555-0 или банкомате нашего банка. постоянный пароль также можно получить в банкомате или перейти по ссылке «не могу войти» в системе сбербанк онлайн. вход в сбербанк онлайн осуществляется с сайта банка по ссылке - https://online.sberbank.ru/csafront/index.do.
# [(3295, 0.93816185), (32601, 0.92400604), (19673, 0.91778558), (16955, 0.91241133), (5871, 0.89611024)]

# %%
#ля получения информации о лимите доступных средств по 
print(utterance_to_result("здоавствуйте, у меня подключен мобильный банк. как можно не выходя из дома проверить остаток на карточке?"))

#test
print(utterance_to_result("могу ли я через мобильный банк проверить остаток карты из дома"))
# Out:
# [(11, 0.31819648912979259), (91, 0.1195716122208394), (109, 0.1124076511508047), (120, 0.34167609935041571)]
#   для получения информации о лимите доступных средств по карте необходимо сформировать и направить на специальный номер оператора мобильной связи 900 или +7(926)200-09-00 или +7(916)572-39-00 с номера телефона, который подключен к услуге «мобильный банк», sms-сообщение следующего формата:  баланс 1234  где 1234 – последние 4 цифры номера вашей карты.  вместо баланс в sms-сообщении могут быть указаны следующие слова: остаток, ostatok, balans, balance, 01.
# [(129, 1.0), (12755, 0.92173624), (4620, 0.92165375), (1840, 0.89224923), (12676, 0.84517926)]
# [(11, 0.42728276827312783), (109, 0.18432927231024115), (120, 0.26588795941662874)]
#  по данному вопросу рекомендуем обратиться в контактный центр банка по телефону 8-800-555-555-0. при наличии технической возможности специалист контактного центра решит ваш вопрос во время звонка.
# [(4620, 0.93786335), (12755, 0.9378444), (1840, 0.93691808), (129, 0.93318623), (12676, 0.88566726)]

# %%
# вадим, в случае утраты карты во избежание ф
print(utterance_to_result("что делать если потерял карточку????  я потерял карточку правда на ней денег  уже не было,  но она мне все равно нужна чтобы потом деньги на неё класть, как её востановить? прийти в банк, и что дальше?"))
#test
print(utterance_to_result("я потерял карточку как ее восстановить"))
# Out:
# [(13, 0.071335279762855572), (34, 0.07016153188319392), (48, 0.083673928618862484), (58, 0.064454793900910204), (64, 0.19725531423758297), (91, 0.23519414143987918), (101, 0.14014596190827033), (140, 0.078612381581782187)]
#   вадим, в случае утраты карты во избежание финансовых потерь необходимо незамедлительно приостановить ее действие. заблокировать карту можно:  • через мобильный банк.  • через сбербанк онл@йн.  • через систему автоматизированного обслуживания.  • позвонив в службу помощи сбербанка по круглосуточным телефонам 8-800-555-55-50 или 8-800-200-37-47.  уточнить информацию о ваших дальнейших действиях более подробно вы можете, обратившись в службу помощи сбербанка.
# [(132, 0.99999911), (17864, 0.81349283), (17848, 0.73114222), (26677, 0.72576213), (495, 0.72027707)]
# [(64, 0.25249772874130078), (91, 0.2508356045920318), (131, 0.25166666666666626)]
# продлить карту можно  на территории рф. для того, чтобы перевыпустить карту не по месту ведения счета, необходимо обратиться в любое отделение банка и подать заявление на перевыпуск карты не по месту ведения счета. в заявлении необходимо указать номер офиса банка, в котором будет удобнее всего получить перевыпущенную карту.
# [(17864, 0.8164981), (36312, 0.76300561), (27592, 0.74103832), (495, 0.73246938), (13851, 0.73045051)]

# %%
#если вам было отказано в получении кредита в нашем банке, то повторно подать за
print(utterance_to_result("через какое время можно подать повторную заявку на кредит ?"))
#test
print(utterance_to_result("я подала заявку на кредит наличными мне отказали когда я смогу подать новую"))
# Out:
# [(36, 0.065026865627664118), (118, 0.21533254620268505), (125, 0.14381053147040956), (137, 0.43678243765162178)]
#  если вам было отказано в получении кредита в нашем банке, то повторно подать заявку вы можете по истечении 60 дней с момента получения отказа.
# [(2732, 0.98584861), (12023, 0.95121658), (28800, 0.94914788), (18859, 0.94851738), (3179, 0.94510144)]
# [(59, 0.11185185185185187), (81, 0.11185183934914621), (100, 0.11185186435455755), (137, 0.55629629628755017)]
#  подать заявку на кредит возможно только непосредственно в отделении банка.
# [(7333, 0.94437099), (31208, 0.94437099), (19478, 0.9324187), (22214, 0.93169063), (22208, 0.93168575)]
